# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from pptoolbox.visualization import initialize_theme
cmaps = initialize_theme()
# Out:
# Registered profileprint_light_cmap
# Registered profileprint_diverging_cmap

# %% [markdown]
# # import and preprocess

# %%
pulldate = '250218'

# %%
label_num_df = pd.read_csv(f'../data/raw/info_num_{pulldate}.csv')
label_num_df
# Out:
#      lot_id     lot_name  property_name  property_value  company_id  \
# 0     69163  MRKU8144625  Sensory Value            1.67        1243
# 1     69164  GESU1118008  Sensory Value            1.83        1243
# 2     69165  PCIU1703142  Sensory Value            1.80        1243
# 3     69166  MSKU4082229  Sensory Value            1.83        1243
# 4     69169  HASU1260204  Sensory Value            0.25        1243
# ..      ...          ...            ...             ...         ...
# 774   90820  CAAU2223430  Sensory Value            0.71        1243
# 775   90821  CAAU2225577  Sensory Value            0.80        1243
# 776   90941  WHSU0152695  Sensory Value            0.14        1243
# 777   90942  WHSU0177902  Sensory Value            0.57        1243
# 778   90943  SEGU2176282  Sensory Value            0.80        1243
#
#      product_type_id  product_name
# 0               6579  Cocoa Butter
# 1               6579  Cocoa Butter
# 2               6579  Cocoa Butter
# 3               6579  Cocoa Butter
# 4               6579  Cocoa Butter
# ..               ...           ...
# 774             6579  Cocoa Butter
# 775             6579  Cocoa Butter
# 776             6579  Cocoa Butter
# 777             6579  Cocoa Butter
# 778             6579  Cocoa Butter
#
# [779 rows x 7 columns]

# %%
label_cat_df = pd.read_csv(f'../data/raw/info_cat_{pulldate}.csv')
label_cat_df
# Out:
#        lot_id     lot_name                          property_name  \
# 0       69163  MRKU8144625                    Deodorization Level
# 1       69163  MRKU8144625                         Sensory Result
# 2       69163  MRKU8144625                                    Ash
# 3       69163  MRKU8144625                                  Fishy
# 4       69163  MRKU8144625                                  Musty
# ...       ...          ...                                    ...
# 15512   90943  SEGU2176282  Oxidized (Old Butter-Stale-Cardboard)
# 15513   90943  SEGU2176282                             Astringent
# 15514   90943  SEGU2176282                                 Earthy
# 15515   90943  SEGU2176282                                 Acetic
# 15516   90943  SEGU2176282                                 Putrid
#
#        property_value  company_id  product_type_id  product_name
# 0      Non-Deodorized        1243             6579  Cocoa Butter
# 1                Fail        1243             6579  Cocoa Butter
# 2             Present        1243             6579  Cocoa Butter
# 3              Absent        1243             6579  Cocoa Butter
# 4              Absent        1243             6579  Cocoa Butter
# ...               ...         ...              ...           ...
# 15512          Absent        1243             6579  Cocoa Butter
# 15513          Absent        1243             6579  Cocoa Butter
# 15514          Absent        1243             6579  Cocoa Butter
# 15515          Absent        1243             6579  Cocoa Butter
# 15516          Absent        1243             6579  Cocoa Butter
#
# [15517 rows x 7 columns]

# %%
raw_df = pd.read_csv(f'../data/raw/spectra_{pulldate}.csv')

# %%
raw_df.head()
# Out:
#    lot_id  specimen_id    lot_name  date_scanned  analyser_id  company_id  \
# 0   78500       470951  06924GOL7A    1727790925           72        1243
# 1   78500       470952  06924GOL7A    1727790942           72        1243
# 2   78500       470953  06924GOL7A    1727790959           72        1243
# 3   78500       470954  06924GOL7A    1727790975           72        1243
# 4   78500       470955  06924GOL7A    1727791033           72        1243
#
#    product_id  product_name  \
# 0        6579  Cocoa Butter
# 1        6579  Cocoa Butter
# 2        6579  Cocoa Butter
# 3        6579  Cocoa Butter
# 4        6579  Cocoa Butter
#
#                                             raw_data  \
# 0  [{"wavelength": 336.2986755371094, "reflectanc...
# 1  [{"wavelength": 336.2986755371094, "reflectanc...
# 2  [{"wavelength": 336.2986755371094, "reflectanc...
# 3  [{"wavelength": 336.2986755371094, "reflectanc...
# 4  [{"wavelength": 336.2986755371094, "reflectanc...
#
#                                        dark_ref_data  \
# 0  [117.8205, 117.8785625, 113.0476875, 116.91393...
# 1  [117.8205, 117.8785625, 113.0476875, 116.91393...
# 2  [117.8205, 117.8785625, 113.0476875, 116.91393...
# 3  [117.8205, 117.8785625, 113.0476875, 116.91393...
# 4  [117.8205, 117.8785625, 113.0476875, 116.91393...
#
#                                       white_ref_data  dark_ref_scan_time  \
# 0  [118.012, 117.7645625, 113.35925, 116.723625, ...          1727790792
# 1  [118.012, 117.7645625, 113.35925, 116.723625, ...          1727790792
# 2  [118.012, 117.7645625, 113.35925, 116.723625, ...          1727790792
# 3  [118.012, 117.7645625, 113.35925, 116.723625, ...          1727790792
# 4  [118.012, 117.7645625, 113.35925, 116.723625, ...          1727790792
#
#    white_ref_scan_time
# 0           1727790833
# 1           1727790833
# 2           1727790833
# 3           1727790833
# 4           1727790833

# %%
raw_df['lot_id'].nunique()
# Out:
# 782

# %%
# what lots are disjoin in raw_df and label_num_df
raw_lots_set = set(raw_df['lot_id'].unique())
label_num_set = set(label_num_df['lot_id'].unique())
label_cat_set = set(label_cat_df['lot_id'].unique())

print (f"missing num labels for {raw_lots_set - label_num_set}")
print (f"missing cat labels for {raw_lots_set - label_cat_set}")

#which set is larger
len(raw_lots_set), len(label_num_set), len(label_cat_set)
# Out:
# missing num labels for {73883, 74047, 69191}
# missing cat labels for set()
# (782, 779, 782)

# %%
# filter labels to only contain those with same lot id as raw_df
label_num_df_clean = label_num_df[label_num_df['lot_id'].isin(raw_df['lot_id'])]
label_cat_df_clean = label_cat_df[label_cat_df['lot_id'].isin(raw_df['lot_id'])]

label_num_df_clean['lot_id'].nunique(), label_cat_df_clean['lot_id'].nunique()
# Out:
# (779, 782)

# %%
label_cat_df_clean = label_cat_df_clean.pivot(index=['lot_id','lot_name'],columns=['property_name'],values='property_value')

# %%
label_cat_df_clean
# Out:
# property_name       Acetic      Ash Astringent   Bitter Brown Fruit  \
# lot_id lot_name
# 69163  MRKU8144625  Absent  Present     Absent  Present     Present
# 69164  GESU1118008  Absent  Present     Absent   Absent      Absent
# 69165  PCIU1703142  Absent  Present     Absent  Present      Absent
# 69166  MSKU4082229  Absent  Present     Absent   Absent      Absent
# 69169  HASU1260204  Absent   Absent     Absent  Present      Absent
# ...                    ...      ...        ...      ...         ...
# 90820  CAAU2223430  Absent   Absent     Absent  Present      Absent
# 90821  CAAU2225577  Absent   Absent     Absent   Absent      Absent
# 90941  WHSU0152695  Absent   Absent     Absent   Absent      Absent
# 90942  WHSU0177902  Absent   Absent     Absent  Present      Absent
# 90943  SEGU2176282  Absent   Absent     Absent  Present      Absent
#
# property_name      Cacao (Chocolate)   Carbon Deodorization Level  Earthy  \
# lot_id lot_name
# 69163  MRKU8144625            Absent  Present      Non-Deodorized  Absent
# 69164  GESU1118008           Present  Present      Non-Deodorized  Absent
# 69165  PCIU1703142           Present  Present      Non-Deodorized  Absent
# 69166  MSKU4082229            Absent   Absent      Non-Deodorized  Absent
# 69169  HASU1260204           Present  Present      Non-Deodorized  Absent
# ...                              ...      ...                 ...     ...
# 90820  CAAU2223430           Present  Present      Non-Deodorized  Absent
# 90821  CAAU2225577            Absent  Present      Non-Deodorized  Absent
# 90941  WHSU0152695           Present   Absent      Non-Deodorized  Absent
# 90942  WHSU0177902           Present  Present      Non-Deodorized  Absent
# 90943  SEGU2176282           Present  Present      Non-Deodorized  Absent
#
# property_name         Fishy Heated Fat (Oil)    Musty  \
# lot_id lot_name
# 69163  MRKU8144625   Absent          Present   Absent
# 69164  GESU1118008   Absent          Present   Absent
# 69165  PCIU1703142  Present          Present   Absent
# 69166  MSKU4082229   Absent           Absent  Present
# 69169  HASU1260204   Absent          Present   Absent
# ...                     ...              ...      ...
# 90820  CAAU2223430   Absent          Present   Absent
# 90821  CAAU2225577   Absent           Absent   Absent
# 90941  WHSU0152695   Absent          Present   Absent
# 90942  WHSU0177902   Absent           Absent   Absent
# 90943  SEGU2176282   Absent          Present   Absent
#
# property_name      Oxidized (Old Butter-Stale-Cardboard)  \
# lot_id lot_name
# 69163  MRKU8144625                                Absent
# 69164  GESU1118008                                Absent
# 69165  PCIU1703142                               Present
# 69166  MSKU4082229                                Absent
# 69169  HASU1260204                                Absent
# ...                                                  ...
# 90820  CAAU2223430                                Absent
# 90821  CAAU2225577                                Absent
# 90941  WHSU0152695                                Absent
# 90942  WHSU0177902                                Absent
# 90943  SEGU2176282                                Absent
#
# property_name      Painty (Solvent-Chemical) Petroleum (Motor Oil-Rubber)  \
# lot_id lot_name
# 69163  MRKU8144625                   Present                      Present
# 69164  GESU1118008                    Absent                       Absent
# 69165  PCIU1703142                    Absent                       Absent
# 69166  MSKU4082229                   Present                      Present
# 69169  HASU1260204                    Absent                       Absent
# ...                                      ...                          ...
# 90820  CAAU2223430                    Absent                       Absent
# 90821  CAAU2225577                    Absent                       Absent
# 90941  WHSU0152695                    Absent                       Absent
# 90942  WHSU0177902                    Absent                       Absent
# 90943  SEGU2176282                    Absent                       Absent
#
# property_name       Putrid Sensory Result    Smoky     Sour Straw (Hay)
# lot_id lot_name
# 69163  MRKU8144625  Absent           Fail  Present   Absent      Absent
# 69164  GESU1118008  Absent           Fail  Present   Absent      Absent
# 69165  PCIU1703142  Absent           Fail  Present  Present     Present
# 69166  MSKU4082229  Absent           Fail  Present   Absent      Absent
# 69169  HASU1260204  Absent           Pass   Absent   Absent      Absent
# ...                    ...            ...      ...      ...         ...
# 90820  CAAU2223430  Absent           Pass   Absent   Absent      Absent
# 90821  CAAU2225577  Absent           Pass   Absent  Present      Absent
# 90941  WHSU0152695  Absent           Pass   Absent   Absent     Present
# 90942  WHSU0177902  Absent           Pass   Absent   Absent     Present
# 90943  SEGU2176282  Absent           Pass   Absent   Absent     Present
#
# [782 rows x 20 columns]

# %%
label_num_df_clean = label_num_df_clean.pivot(index=['lot_id','lot_name'],columns=['property_name'],values='property_value')

# %%
label_num_df_clean
# Out:
# property_name       Sensory Value
# lot_id lot_name
# 69163  MRKU8144625           1.67
# 69164  GESU1118008           1.83
# 69165  PCIU1703142           1.80
# 69166  MSKU4082229           1.83
# 69169  HASU1260204           0.25
# ...                           ...
# 90820  CAAU2223430           0.71
# 90821  CAAU2225577           0.80
# 90941  WHSU0152695           0.14
# 90942  WHSU0177902           0.57
# 90943  SEGU2176282           0.80
#
# [779 rows x 1 columns]

# %%
label_df_clean = pd.merge( label_cat_df_clean,label_num_df_clean, on=['lot_id','lot_name'], how='outer')
label_df_clean
# Out:
# property_name       Acetic      Ash Astringent   Bitter Brown Fruit  \
# lot_id lot_name
# 69163  MRKU8144625  Absent  Present     Absent  Present     Present
# 69164  GESU1118008  Absent  Present     Absent   Absent      Absent
# 69165  PCIU1703142  Absent  Present     Absent  Present      Absent
# 69166  MSKU4082229  Absent  Present     Absent   Absent      Absent
# 69169  HASU1260204  Absent   Absent     Absent  Present      Absent
# ...                    ...      ...        ...      ...         ...
# 90820  CAAU2223430  Absent   Absent     Absent  Present      Absent
# 90821  CAAU2225577  Absent   Absent     Absent   Absent      Absent
# 90941  WHSU0152695  Absent   Absent     Absent   Absent      Absent
# 90942  WHSU0177902  Absent   Absent     Absent  Present      Absent
# 90943  SEGU2176282  Absent   Absent     Absent  Present      Absent
#
# property_name      Cacao (Chocolate)   Carbon Deodorization Level  Earthy  \
# lot_id lot_name
# 69163  MRKU8144625            Absent  Present      Non-Deodorized  Absent
# 69164  GESU1118008           Present  Present      Non-Deodorized  Absent
# 69165  PCIU1703142           Present  Present      Non-Deodorized  Absent
# 69166  MSKU4082229            Absent   Absent      Non-Deodorized  Absent
# 69169  HASU1260204           Present  Present      Non-Deodorized  Absent
# ...                              ...      ...                 ...     ...
# 90820  CAAU2223430           Present  Present      Non-Deodorized  Absent
# 90821  CAAU2225577            Absent  Present      Non-Deodorized  Absent
# 90941  WHSU0152695           Present   Absent      Non-Deodorized  Absent
# 90942  WHSU0177902           Present  Present      Non-Deodorized  Absent
# 90943  SEGU2176282           Present  Present      Non-Deodorized  Absent
#
# property_name         Fishy  ...    Musty  \
# lot_id lot_name              ...
# 69163  MRKU8144625   Absent  ...   Absent
# 69164  GESU1118008   Absent  ...   Absent
# 69165  PCIU1703142  Present  ...   Absent
# 69166  MSKU4082229   Absent  ...  Present
# 69169  HASU1260204   Absent  ...   Absent
# ...                     ...  ...      ...
# 90820  CAAU2223430   Absent  ...   Absent
# 90821  CAAU2225577   Absent  ...   Absent
# 90941  WHSU0152695   Absent  ...   Absent
# 90942  WHSU0177902   Absent  ...   Absent
# 90943  SEGU2176282   Absent  ...   Absent
#
# property_name      Oxidized (Old Butter-Stale-Cardboard)  \
# lot_id lot_name
# 69163  MRKU8144625                                Absent
# 69164  GESU1118008                                Absent
# 69165  PCIU1703142                               Present
# 69166  MSKU4082229                                Absent
# 69169  HASU1260204                                Absent
# ...                                                  ...
# 90820  CAAU2223430                                Absent
# 90821  CAAU2225577                                Absent
# 90941  WHSU0152695                                Absent
# 90942  WHSU0177902                                Absent
# 90943  SEGU2176282                                Absent
#
# property_name      Painty (Solvent-Chemical) Petroleum (Motor Oil-Rubber)  \
# lot_id lot_name
# 69163  MRKU8144625                   Present                      Present
# 69164  GESU1118008                    Absent                       Absent
# 69165  PCIU1703142                    Absent                       Absent
# 69166  MSKU4082229                   Present                      Present
# 69169  HASU1260204                    Absent                       Absent
# ...                                      ...                          ...
# 90820  CAAU2223430                    Absent                       Absent
# 90821  CAAU2225577                    Absent                       Absent
# 90941  WHSU0152695                    Absent                       Absent
# 90942  WHSU0177902                    Absent                       Absent
# 90943  SEGU2176282                    Absent                       Absent
#
# property_name       Putrid Sensory Result    Smoky     Sour Straw (Hay)  \
# lot_id lot_name
# 69163  MRKU8144625  Absent           Fail  Present   Absent      Absent
# 69164  GESU1118008  Absent           Fail  Present   Absent      Absent
# 69165  PCIU1703142  Absent           Fail  Present  Present     Present
# 69166  MSKU4082229  Absent           Fail  Present   Absent      Absent
# 69169  HASU1260204  Absent           Pass   Absent   Absent      Absent
# ...                    ...            ...      ...      ...         ...
# 90820  CAAU2223430  Absent           Pass   Absent   Absent      Absent
# 90821  CAAU2225577  Absent           Pass   Absent  Present      Absent
# 90941  WHSU0152695  Absent           Pass   Absent   Absent     Present
# 90942  WHSU0177902  Absent           Pass   Absent   Absent     Present
# 90943  SEGU2176282  Absent           Pass   Absent   Absent     Present
#
# property_name      Sensory Value
# lot_id lot_name
# 69163  MRKU8144625          1.67
# 69164  GESU1118008          1.83
# 69165  PCIU1703142          1.80
# 69166  MSKU4082229          1.83
# 69169  HASU1260204          0.25
# ...                          ...
# 90820  CAAU2223430          0.71
# 90821  CAAU2225577          0.80
# 90941  WHSU0152695          0.14
# 90942  WHSU0177902          0.57
# 90943  SEGU2176282          0.80
#
# [782 rows x 21 columns]

# %%
# Identify columns with NA
na_columns = label_df_clean.columns[label_df_clean.isna().any()]

# Display rows with NA, showing only affected columns
display(label_df_clean.loc[label_df_clean.isna().any(axis=1), na_columns])
# Out:
# property_name              Acetic Astringent   Earthy  Putrid  Sensory Value
# lot_id lot_name
# 69191  HASU1010210         Absent     Absent   Absent  Absent            NaN
# 70153  STJU2025162            NaN        NaN      NaN     NaN           0.17
# 70166  PONU2033293            NaN        NaN  Present     NaN           0.50
# 70354  MSKU6916110            NaN        NaN      NaN     NaN           0.38
# 70378  TLLU2480651            NaN        NaN      NaN     NaN           1.11
# 70395  MRKU6201808            NaN        NaN      NaN     NaN           1.33
# 73883  HLBU3004302         Absent     Absent   Absent  Absent            NaN
# 74047  TCLU1977537         Absent     Absent   Absent  Absent            NaN
# 76894  250424311              NaN        NaN      NaN     NaN           1.50
# 78569  MRKU6804165            NaN        NaN      NaN     NaN           1.25
# 78582  WHLU0511357            NaN        NaN      NaN     NaN           0.75
# 83273  CAIU4207596            NaN        NaN      NaN     NaN           0.70
# 83318  ICCU9160463            NaN        NaN      NaN     NaN           0.30
# 83319  SEGU5890380            NaN        NaN      NaN     NaN           0.30
# 84066  SEKU5598460            NaN        NaN      NaN     NaN           0.38
# 84067  BSIU9923990            NaN        NaN      NaN     NaN           0.25
# 84068  CAIU4204180            NaN        NaN      NaN     NaN           0.63
# 84069  CAIU4204935            NaN        NaN      NaN     NaN           0.67
# 84070  BSIU9979411            NaN        NaN      NaN     NaN           0.22
# 84071  GAOU6427156            NaN        NaN      NaN     NaN           0.22
# 84072  TCNU3432894            NaN        NaN      NaN     NaN           0.50
# 84073  CAIU4200544            NaN        NaN      NaN     NaN           0.25
# 84074  ICUU9161496            NaN        NaN      NaN     NaN           0.50
# 84093  HASU1306199            NaN        NaN      NaN     NaN           1.17
# 84276  SEKU6374716            NaN        NaN      NaN     NaN           0.14
# 84277  TLLU8867397            NaN        NaN      NaN     NaN           0.00
# 84278  TLLU8039427            NaN        NaN      NaN     NaN           0.43
# 84279  GAOU6431650            NaN        NaN      NaN     NaN           0.22
# 84280  TCNU3430633            NaN        NaN      NaN     NaN           0.44
# 84371  GAOU6424291            NaN        NaN      NaN     NaN           0.43
# 84372  GAOU6721880            NaN        NaN      NaN     NaN           0.57
# 84373  ICUU9223324            NaN        NaN      NaN     NaN           0.29
# 84917  D4295402 - DEO         NaN        NaN      NaN     NaN           0.00
# 84918  D4295402 - NON-DEO     NaN        NaN      NaN     NaN           2.00

# %%
#drop rows with NA
label_df_clean_removena = label_df_clean.dropna(axis=0)
print(f"Number of rows before removing NA: {label_df_clean.shape[0]}")
print(f"Number of rows after removing NA: {label_df_clean_removena.shape[0]}")

num_cols = len(label_df_clean_removena.columns)
rows = int(np.ceil(num_cols / 4))  # Calculate required rows dynamically
fig, ax = plt.subplots(rows, 4, figsize=(20, 5 * rows))
fig.suptitle('Label Distribution for full\n\n', fontsize=20)

# Flatten ax to avoid indexing issues when rows < 4
ax = ax.flatten()

for i, col in enumerate(label_df_clean_removena.columns):
    if label_df_clean_removena[col].dtype == 'float64':
        sns.histplot(label_df_clean_removena[col], ax=ax[i])
        ax[i].set_title(f'{col}')
    else:
        value_counts = label_df_clean_removena[col].value_counts()
        total = value_counts.sum()  # Get total count for percentage
        sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax[i])
        ax[i].set_title(f'{col}')
        
        # Add percentage labels
        for j, value in enumerate(value_counts.values):
            percentage = (value / total) * 100
            ax[i].text(j, value + 0.01 * max(value_counts.values), f'{percentage:.1f}%', ha='center', fontsize=12, color='black')


# Hide any unused subplots
for j in range(i + 1, len(ax)):
    fig.delaxes(ax[j])

plt.savefig(f'../data/processed/label_distribution_combined_{pulldate}.png', bbox_inches='tight')
plt.show()
# Out:
# Number of rows before removing NA: 782
# Number of rows after removing NA: 748

# %%
output_dir = Path(f"../data/processed")
output_dir.mkdir(exist_ok=True, parents=True)

label_df_output = label_df_clean.reset_index().set_index('lot_id')

label_df_output.to_csv(output_dir/f"label_{pulldate}.csv")
label_df_output.shape
# Out:
# (782, 22)

# %%
output_dir = Path(f"../data/processed")
label_df = pd.read_csv(output_dir/f"label_{pulldate}.csv")
label_df = label_df.set_index(['lot_id','lot_name'])
label_df
# Out:
#                     Acetic      Ash Astringent   Bitter Brown Fruit  \
# lot_id lot_name
# 69163  MRKU8144625  Absent  Present     Absent  Present     Present
# 69164  GESU1118008  Absent  Present     Absent   Absent      Absent
# 69165  PCIU1703142  Absent  Present     Absent  Present      Absent
# 69166  MSKU4082229  Absent  Present     Absent   Absent      Absent
# 69169  HASU1260204  Absent   Absent     Absent  Present      Absent
# ...                    ...      ...        ...      ...         ...
# 90820  CAAU2223430  Absent   Absent     Absent  Present      Absent
# 90821  CAAU2225577  Absent   Absent     Absent   Absent      Absent
# 90941  WHSU0152695  Absent   Absent     Absent   Absent      Absent
# 90942  WHSU0177902  Absent   Absent     Absent  Present      Absent
# 90943  SEGU2176282  Absent   Absent     Absent  Present      Absent
#
#                    Cacao (Chocolate)   Carbon Deodorization Level  Earthy  \
# lot_id lot_name
# 69163  MRKU8144625            Absent  Present      Non-Deodorized  Absent
# 69164  GESU1118008           Present  Present      Non-Deodorized  Absent
# 69165  PCIU1703142           Present  Present      Non-Deodorized  Absent
# 69166  MSKU4082229            Absent   Absent      Non-Deodorized  Absent
# 69169  HASU1260204           Present  Present      Non-Deodorized  Absent
# ...                              ...      ...                 ...     ...
# 90820  CAAU2223430           Present  Present      Non-Deodorized  Absent
# 90821  CAAU2225577            Absent  Present      Non-Deodorized  Absent
# 90941  WHSU0152695           Present   Absent      Non-Deodorized  Absent
# 90942  WHSU0177902           Present  Present      Non-Deodorized  Absent
# 90943  SEGU2176282           Present  Present      Non-Deodorized  Absent
#
#                       Fishy  ...    Musty  \
# lot_id lot_name              ...
# 69163  MRKU8144625   Absent  ...   Absent
# 69164  GESU1118008   Absent  ...   Absent
# 69165  PCIU1703142  Present  ...   Absent
# 69166  MSKU4082229   Absent  ...  Present
# 69169  HASU1260204   Absent  ...   Absent
# ...                     ...  ...      ...
# 90820  CAAU2223430   Absent  ...   Absent
# 90821  CAAU2225577   Absent  ...   Absent
# 90941  WHSU0152695   Absent  ...   Absent
# 90942  WHSU0177902   Absent  ...   Absent
# 90943  SEGU2176282   Absent  ...   Absent
#
#                    Oxidized (Old Butter-Stale-Cardboard)  \
# lot_id lot_name
# 69163  MRKU8144625                                Absent
# 69164  GESU1118008                                Absent
# 69165  PCIU1703142                               Present
# 69166  MSKU4082229                                Absent
# 69169  HASU1260204                                Absent
# ...                                                  ...
# 90820  CAAU2223430                                Absent
# 90821  CAAU2225577                                Absent
# 90941  WHSU0152695                                Absent
# 90942  WHSU0177902                                Absent
# 90943  SEGU2176282                                Absent
#
#                    Painty (Solvent-Chemical) Petroleum (Motor Oil-Rubber)  \
# lot_id lot_name
# 69163  MRKU8144625                   Present                      Present
# 69164  GESU1118008                    Absent                       Absent
# 69165  PCIU1703142                    Absent                       Absent
# 69166  MSKU4082229                   Present                      Present
# 69169  HASU1260204                    Absent                       Absent
# ...                                      ...                          ...
# 90820  CAAU2223430                    Absent                       Absent
# 90821  CAAU2225577                    Absent                       Absent
# 90941  WHSU0152695                    Absent                       Absent
# 90942  WHSU0177902                    Absent                       Absent
# 90943  SEGU2176282                    Absent                       Absent
#
#                     Putrid Sensory Result    Smoky     Sour Straw (Hay)  \
# lot_id lot_name
# 69163  MRKU8144625  Absent           Fail  Present   Absent      Absent
# 69164  GESU1118008  Absent           Fail  Present   Absent      Absent
# 69165  PCIU1703142  Absent           Fail  Present  Present     Present
# 69166  MSKU4082229  Absent           Fail  Present   Absent      Absent
# 69169  HASU1260204  Absent           Pass   Absent   Absent      Absent
# ...                    ...            ...      ...      ...         ...
# 90820  CAAU2223430  Absent           Pass   Absent   Absent      Absent
# 90821  CAAU2225577  Absent           Pass   Absent  Present      Absent
# 90941  WHSU0152695  Absent           Pass   Absent   Absent     Present
# 90942  WHSU0177902  Absent           Pass   Absent   Absent     Present
# 90943  SEGU2176282  Absent           Pass   Absent   Absent     Present
#
#                    Sensory Value
# lot_id lot_name
# 69163  MRKU8144625          1.67
# 69164  GESU1118008          1.83
# 69165  PCIU1703142          1.80
# 69166  MSKU4082229          1.83
# 69169  HASU1260204          0.25
# ...                          ...
# 90820  CAAU2223430          0.71
# 90821  CAAU2225577          0.80
# 90941  WHSU0152695          0.14
# 90942  WHSU0177902          0.57
# 90943  SEGU2176282          0.80
#
# [782 rows x 21 columns]

# %% [markdown]
# # split deo and nondeo

# %%
deo_label_df = label_df.select_dtypes(include='object')[label_df['Deodorization Level']=='Deodorized'].reset_index().drop(columns=['Deodorization Level','lot_name'])
deo_label_df = pd.merge(deo_label_df, label_df.select_dtypes(include='float64'), on='lot_id')
deo_label_df = deo_label_df.set_index('lot_id')

nondeo_label_df = label_df.select_dtypes(include='object')[label_df['Deodorization Level']=='Non-Deodorized'].reset_index().drop(columns=['Deodorization Level','lot_name'])
nondeo_label_df = pd.merge(nondeo_label_df, label_df.select_dtypes(include='float64'), on='lot_id')
nondeo_label_df = nondeo_label_df.set_index('lot_id')

print(deo_label_df.shape, nondeo_label_df.shape)
# Out:
# (248, 20) (534, 20)

# %%
datasets = {
    'deo': deo_label_df,
    'nondeo': nondeo_label_df
}

# %%
#count number of rows with NA in each dataset
for key in datasets.keys():
    print(f"Number of rows with NA in {key} dataset: {datasets[key].isna().any(axis=1).sum()}")
# Out:
# Number of rows with NA in deo dataset: 3
# Number of rows with NA in nondeo dataset: 31

# %%
for dataset in datasets:
    print(f"Label Distribution for {dataset}")
    df = datasets[dataset]

    print(f"Number of rows before removing NA: {df.shape[0]}")
    df = df.dropna(axis=0)
    print(f"Number of rows after removing NA: {df.dropna(axis=0).shape[0]}")

    num_cols = len(df.columns)
    rows = int(np.ceil(num_cols / 4))  # Calculate required rows dynamically
    fig, ax = plt.subplots(rows, 4, figsize=(20, 5 * rows))
    fig.suptitle(f"Label Distribution for {dataset}\n\n", fontsize=20)

    # Flatten ax to avoid indexing issues when rows < 4
    ax = ax.flatten()

    for i, col in enumerate(df.columns):
        if df[col].dtype == 'float64':
            sns.histplot(df[col], ax=ax[i])
            ax[i].set_title(f'{col}')
        else:
            value_counts = df[col].value_counts()
            total = value_counts.sum()  # Get total count for percentage
            sns.barplot(x=value_counts.index, y=value_counts.values, ax=ax[i])
            ax[i].set_title(f'{col}')
            
            # Add percentage labels
            for j, value in enumerate(value_counts.values):
                percentage = (value / total) * 100
                ax[i].text(j, value + 0.01 * max(value_counts.values), f'{percentage:.1f}%', ha='center', fontsize=12, color='black')


    # Hide any unused subplots
    for j in range(i + 1, len(ax)):
        fig.delaxes(ax[j])

    plt.savefig(f"../data/processed/label_distribution_{dataset}_{pulldate}.png", bbox_inches='tight')
    plt.show()
# Out:
# Label Distribution for deo
# Number of rows before removing NA: 248
# Number of rows after removing NA: 245
# Label Distribution for nondeo
# Number of rows before removing NA: 534
# Number of rows after removing NA: 503
