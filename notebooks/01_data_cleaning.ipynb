# %%
import pandas as pd
import numpy as np
from pathlib import Path
from pptoolbox.platform import preprocess

# %%
raw_folder_path = Path("../data/raw")

version = "inspect_only"
pull_date = "260123"  # Updated pull date

label = pd.read_csv(raw_folder_path / version / f"label_{pull_date}.csv")
spectra = pd.read_csv(raw_folder_path / version / f"spectra_{pull_date}.csv")

print(f"Label shape: {label.shape}")
print(f"Spectra shape: {spectra.shape}")
# Out:
# Label shape: (153, 7)
# Spectra shape: (35, 34)

# %%
label = label.pivot(index=['lot_id'], columns='property_name', values='property_value').reset_index()
label.head()
# Out:
# property_name  lot_id Quality Control Source
# 0               28724            Fail    NaN
# 1               28725            Fail    NaN
# 2               28726            Fail    NaN
# 3               28949            Fail    NaN
# 4               28950            Fail    NaN

# %%
spectra.head()
# Out:
#    lot_id  active  analyzer_id
# 0  113018       1          118  \
# 1  113018       1          118
# 2  113018       1          118
# 3  113018       1          118
# 4  113018       1          118
#
#                                       calc_data_mini
# 0  [{"wavelength": 289.1642150878906, "reflectanc...  \
# 1  [{"wavelength": 289.1642150878906, "reflectanc...
# 2  [{"wavelength": 289.1642150878906, "reflectanc...
# 3  [{"wavelength": 289.1642150878906, "reflectanc...
# 4  [{"wavelength": 289.1642150878906, "reflectanc...
#
#                                        calc_data_neo  company_id
# 0  [{"wavelength": 928.2705078125, "reflectance":...        1065  \
# 1  [{"wavelength": 928.2705078125, "reflectance":...        1065
# 2  [{"wavelength": 928.2705078125, "reflectance":...        1065
# 3  [{"wavelength": 928.2705078125, "reflectance":...        1065
# 4  [{"wavelength": 928.2705078125, "reflectance":...        1065
#
#                                   dark_ref_data_mini
# 0  [-3.1217658519744873, -2.4258341789245605, -0....  \
# 1  [-3.1217658519744873, -2.4258341789245605, -0....
# 2  [-3.1217658519744873, -2.4258341789245605, -0....
# 3  [-3.1217658519744873, -2.4258341789245605, -0....
# 4  [-3.1217658519744873, -2.4258341789245605, -0....
#
#                                    dark_ref_data_neo  dark_ref_scan_time
# 0  [26.758460998535156, 10.878236770629883, -3.83...          1764345570  \
# 1  [26.758460998535156, 10.878236770629883, -3.83...          1764345570
# 2  [26.758460998535156, 10.878236770629883, -3.83...          1764345570
# 3  [26.758460998535156, 10.878236770629883, -3.83...          1764345570
# 4  [26.758460998535156, 10.878236770629883, -3.83...          1764345570
#
#    date_scanned  ...                                 white_ref_data_neo
# 0    1764345888  ...  [883.9205322265625, 1116.41650390625, 1689.150...  \
# 1    1764346114  ...  [883.9205322265625, 1116.41650390625, 1689.150...
# 2    1764346366  ...  [883.9205322265625, 1116.41650390625, 1689.150...
# 3    1764346596  ...  [883.9205322265625, 1116.41650390625, 1689.150...
# 4    1764346857  ...  [883.9205322265625, 1116.41650390625, 1689.150...
#
#    white_ref_scan_time  raw_data  dark_ref_data  white_ref_data  scope_data
# 0           1764345604       NaN            NaN             NaN         NaN  \
# 1           1764345604       NaN            NaN             NaN         NaN
# 2           1764345604       NaN            NaN             NaN         NaN
# 3           1764345604       NaN            NaN             NaN         NaN
# 4           1764345604       NaN            NaN             NaN         NaN
#
#   specimen_id         lot_name product_id                       product_name
# 0      677693  S823 (B1131025)       5449  S823 RASPBERRY 392 IAL (STANDARD)
# 1      677699  S823 (B1131025)       5449  S823 RASPBERRY 392 IAL (STANDARD)
# 2      677703  S823 (B1131025)       5449  S823 RASPBERRY 392 IAL (STANDARD)
# 3      677707  S823 (B1131025)       5449  S823 RASPBERRY 392 IAL (STANDARD)
# 4      677712  S823 (B1131025)       5449  S823 RASPBERRY 392 IAL (STANDARD)
#
# [5 rows x 34 columns]

# %%
label_lot_id = set(label['lot_id'])
spectra_lot_id = set(spectra['lot_id'])

missing_label_lot_ids = spectra_lot_id - label_lot_id
print(f"Missing lot IDs in label: {missing_label_lot_ids}")

missing_spectra_lot_ids = label_lot_id - spectra_lot_id
print(f"Missing lot IDs in spectra: {missing_spectra_lot_ids}")
# Out:
# Missing lot IDs in label: set()
# Missing lot IDs in spectra: {37401, 28724, 28725, 28726, 36409, 36410, 36412, 29266, 29267, 29268, 35925, 35926, 51808, 51809, 51306, 51308, 35456, 35462, 29323, 50831, 50832, 29332, 29341, 38058, 38059, 38060, 38061, 43705, 43706, 43707, 36028, 36029, 43708, 37061, 37064, 37065, 37066, 44243, 44244, 44245, 44246, 36061, 36062, 36063, 36064, 36065, 48386, 51446, 39159, 39160, 39161, 39162, 48387, 48388, 44289, 44290, 44291, 44292, 29445, 29446, 29447, 29448, 29449, 43782, 29451, 43783, 44293, 44294, 48390, 51986, 51987, 51988, 28949, 28950, 28951, 28952, 29462, 28954, 28955, 29463, 29467, 36144, 36145, 36150, 36151, 36152, 48389, 43842, 43844, 38216, 38218, 29515, 29516, 29517, 29518, 29520, 29521, 38226, 38228, 38229, 38232, 52059, 52060, 51037, 51038, 51039, 52061, 52062, 43887, 43888, 37235, 37237, 38774, 37243, 29573, 29574, 29575, 37269, 37270, 29080, 29081, 29082, 38814, 38818, 29610, 29611, 29613, 29616, 29617, 29618, 48613, 48614, 48615, 48616, 48619, 36859, 36860, 36861, 36862}

# %% [markdown]
# # Preprocessing

# %%
X, y, add = preprocess(
    X_input = spectra,
    y_input = label,
    export_meta = True)

meta = add['metadata']

print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
print(f"meta shape: {meta.shape}")
# Out:
# X shape: (35, 391)
# y shape: (35, 2)
# meta shape: (35, 6)

# %%
y.head()
# Out:
#        Quality Control      Source
# lot_id
# 113018            Pass  Production
# 113018            Pass  Production
# 113018            Pass  Production
# 113018            Pass  Production
# 113018            Pass  Production

# %%
assert X.index.equals(y.index), "Indices of X and y do not match!"
assert X.index.equals(meta.index), "Indices of X and y_meta do not match!"

# %%
meta['date_reformatted'] = pd.to_datetime(meta['date_scanned'], unit='s').dt.strftime('%Y-%m-%d')

# %%
meta.head()
# Out:
#         active  analyzer_id  company_id  specimen_id  date_scanned
# lot_id
# 113018       1          118        1065       677693    1764345888  \
# 113018       1          118        1065       677699    1764346114
# 113018       1          118        1065       677703    1764346366
# 113018       1          118        1065       677707    1764346596
# 113018       1          118        1065       677712    1764346857
#
#                lot_name date_reformatted
# lot_id
# 113018  S823 (B1131025)       2025-11-28
# 113018  S823 (B1131025)       2025-11-28
# 113018  S823 (B1131025)       2025-11-28
# 113018  S823 (B1131025)       2025-11-28
# 113018  S823 (B1131025)       2025-11-28

# %%
output_path = Path ("../data/processed") / version / "full"
output_path.mkdir(parents=True, exist_ok=True)
X.to_csv(output_path / f"input.csv")
y.to_csv(output_path / f"label.csv")
meta.to_csv(output_path / f"meta.csv")
